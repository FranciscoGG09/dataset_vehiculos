# %%
# examine_dataset.py
import pandas as pd

# Cargar el dataset
df = pd.read_csv('car details v3.csv')

print("🔍 Análisis del dataset CarDekho:")
print(f"📊 Forma del dataset: {df.shape}")
print(f"📋 Columnas: {list(df.columns)}")
print(f"📝 Tipos de datos:\n{df.dtypes}")
print(f"🔢 Valores nulos:\n{df.isnull().sum()}")
print(f"📈 Primeras filas:\n{df.head(3)}")
# Out:
# La ejecución de celdas con 'vehicles_env (Python 3.13.7)' requiere el paquete ipykernel.
#
# Instale "ipykernel" en el entorno de Python.
#
# Comando: ""c:/Users/Francisco Gonzalez/Documents/tripleTen/dataset_vehicles/vehicles_env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall"
